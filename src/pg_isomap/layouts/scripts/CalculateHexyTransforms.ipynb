# %%
import scalatrix as sx

# %%
hex_transforms = {
    'skew_up': sx.affineFromThreeDots(
        sx.Vector2d(0, 0),
        sx.Vector2d(1, 0),
        sx.Vector2d(0, 1),
        sx.Vector2d(0, 0),
        sx.Vector2d(1, -1),
        sx.Vector2d(0, 1)    
    ),
    'skew_down': sx.affineFromThreeDots(
        sx.Vector2d(0, 0),
        sx.Vector2d(1, 0),
        sx.Vector2d(0, 1),
        sx.Vector2d(0, 0),
        sx.Vector2d(1, 1),
        sx.Vector2d(0, 1)    
    ),
    'skew_upleft': sx.affineFromThreeDots(
        sx.Vector2d(0, 0),
        sx.Vector2d(1, 0),
        sx.Vector2d(0, 1),
        sx.Vector2d(0, 0),
        sx.Vector2d(2, -1),
        sx.Vector2d(1, 0)    
    ),
    'skew_downright': sx.affineFromThreeDots(
        sx.Vector2d(0, 0),
        sx.Vector2d(1, 0),
        sx.Vector2d(0, 1),
        sx.Vector2d(0, 0),
        sx.Vector2d(0, 1),
        sx.Vector2d(-1, 2)    
    ),
    'rotate_left_hex': sx.affineFromThreeDots(
        sx.Vector2d(0, 0),
        sx.Vector2d(1, 0),
        sx.Vector2d(0, 1),
        sx.Vector2d(0, 0),
        sx.Vector2d(0, 1),
        sx.Vector2d(-1, 1)
    ),
    'rotate_right_hex': sx.affineFromThreeDots(
        sx.Vector2d(0, 0),
        sx.Vector2d(1, 0),
        sx.Vector2d(0, 1),
        sx.Vector2d(0, 0),
        sx.Vector2d(1, -1),
        sx.Vector2d(1, 0)
    ),
    'reflect_x_hex': sx.affineFromThreeDots(
        sx.Vector2d(0, 0),
        sx.Vector2d(1, 0),
        sx.Vector2d(0, 1),
        sx.Vector2d(0, 0),
        sx.Vector2d(1, 0),
        sx.Vector2d(1, -1)
    ),
    'reflect_y_hex': sx.affineFromThreeDots(
        sx.Vector2d(0, 0),
        sx.Vector2d(1, 0),
        sx.Vector2d(0, 1),
        sx.Vector2d(0, 0),
        sx.Vector2d(-1, 1),
        sx.Vector2d(0, 1)
    ),
    'reflect_xy_hex': sx.affineFromThreeDots(
        sx.Vector2d(0, 0),
        sx.Vector2d(1, 0),
        sx.Vector2d(0, 1),
        sx.Vector2d(0, 0),
        sx.Vector2d(0, -1),
        sx.Vector2d(-1, 0)
    )
}

# %%
for name, transform in hex_transforms.items():
    print(f"            elif transform_type == '{name}':")
    print(f"                delta = sx.IntegerAffineTransform({int(transform.a)}, {int(transform.b)}, {int(transform.c)}, {int(transform.d)}, {int(transform.tx)}, {int(transform.ty)})")
# Out:
#             elif transform_type == 'skew_up':
#                 delta = sx.IntegerAffineTransform(1, 0, -1, 1, 0, 0)
#             elif transform_type == 'skew_down':
#                 delta = sx.IntegerAffineTransform(1, 0, 1, 1, 0, 0)
#             elif transform_type == 'skew_upleft':
#                 delta = sx.IntegerAffineTransform(2, 1, -1, 0, 0, 0)
#             elif transform_type == 'skew_downright':
#                 delta = sx.IntegerAffineTransform(0, -1, 1, 2, 0, 0)
#             elif transform_type == 'rotate_left_hex':
#                 delta = sx.IntegerAffineTransform(0, -1, 1, 1, 0, 0)
#             elif transform_type == 'rotate_right_hex':
#                 delta = sx.IntegerAffineTransform(1, 1, -1, 0, 0, 0)
#             elif transform_type == 'reflect_x_hex':
#                 delta = sx.IntegerAffineTransform(1, 1, 0, -1, 0, 0)
#             elif transform_type == 'reflect_y_hex':
#                 delta = sx.IntegerAffineTransform(-1, 0, 1, 1, 0, 0)
# ...

# %%
)

# %%
def 
shear_up
# Out:
# AffineTransform(a=1.000000, b=0.000000, c=-1.000000, d=1.000000, tx=0.000000, ty=0.000000)
